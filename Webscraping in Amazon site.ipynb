# %%
from bs4 import BeautifulSoup
import time
import requests
import datetime
import csv
import pandas as pd

# %%
#Connection

url="https://www.amazon.com/50Pcs-5-Ply-Black-Shields-Filter/dp/B09F69FVL5/ref=sr_1_2_sspa?keywords=kn95%2Bface%2Bmasks&qid=1641952503&sprefix=kn%2Caps%2C116&sr=8-2-spons&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUExNjJFM1Y4TEY2Wk05JmVuY3J5cHRlZElkPUEwMDc3NDA5MkxRWjVTWEFDMFU5QSZlbmNyeXB0ZWRBZElkPUEwNzE2ODEyMks1UVlQQkhRNVhUVSZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU&th=1"
headers={"User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36"}

page=requests.get(url, headers=headers)

soup1=BeautifulSoup(page.content,"html.parser")
soup2=BeautifulSoup(soup1.prettify(),"html.parser")
soup2
# Out:
# <!DOCTYPE html>
#
# <!--[if lt IE 7]> <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8 a-lt-ie7"> <![endif]-->
# <!--[if IE 7]>    <html lang="en-us" class="a-no-js a-lt-ie9 a-lt-ie8"> <![endif]-->
# <!--[if IE 8]>    <html lang="en-us" class="a-no-js a-lt-ie9"> <![endif]-->
# <!--[if gt IE 8]><!-->
# <html class="a-no-js" lang="en-us">
# <!--<![endif]-->
# <head>
# <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
# <meta charset="utf-8"/>
# <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
# <title dir="ltr">
#    Amazon.com
#   </title>
# <meta content="width=device-width" name="viewport"/>
# <link href="https://images-na.ssl-images-amazon.com/images/G/01/AUIClients/AmazonUI-3c913031596ca78a3768f4e934b1cc02ce238101.secure.min._V1_.css" rel="stylesheet"/>
# <script>
#    if (true === true) {
#     var ue_t0 = (+ new Date()),
#         ue_csm = window,
#         ue = { t0: ue_t0, d: function() { return (+new Date() - ue_t0); } },
# ...

# %%
#Getting the product title
title=soup2.find(id="productTitle").get_text()
# print(title)
#Getting the price details
price_all=soup2.find_all("span",{"class":"a-offscreen"})
price=price_all[0].get_text()
# print(price)
#Getting rating information
rating_all=soup2.find_all("span",{"class":"a-icon-alt"})
rating=rating_all[0].get_text()
# print(rating)

title=title.strip()
price=price.strip()[1:]
price=float(price)
rating=rating.strip()[:3]
rating=float(rating)
date=datetime.date.today()
#Scraped data
print("Product title: ",title)
print("Price: ",price)
print("Rating: ",rating)
print("Date: ",date)
;

# %%
#Export data to csv

header=['Title','Price','Rating','Date']

data=[title,price,rating,date]

with open('Amazon_Scraper_dataset.csv','w',newline='',encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(header)
    writer.writerow(data)

# %%
df=pd.read_csv("Amazon_Scraper_dataset.csv")
df
# Out:
#                                                Title  Price  Rating  \
# 0  60PCS Multicolor KF94 Mask , 4 Layer Protectiv...  35.79     4.5
#
#          Date
# 0  2022-01-11

# %%
#Creating an automated scraper function for the product

def check_prod:
    url="https://www.amazon.com/Multicolor-Protective-Shields-Elastic-Grey/dp/B09P3L6D1K/ref=sr_1_2_sspa?keywords=kn95%2Bface%2Bmasks&qid=1641941355&sprefix=masks%2Caps%2C83&sr=8-2-spons&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyTzEwVExKVExTREdaJmVuY3J5cHRlZElkPUEwMDI4OTU4MUY0RktJQ1k5RTdBMCZlbmNyeXB0ZWRBZElkPUEwNjk5MDA0MTBaNU9ES0lMR0c4RyZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU&th=1"
    headers={"User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/97.0.4692.71 Safari/537.36", "Accept-Encoding":"gzip, deflate", "Accept":"text/html,application/xhtml+xml,application/xml;q=0.9,*/*;q=0.8", "DNT":"1","Connection":"close", "Upgrade-Insecure-Requests":"1"}

    page=requests.get(url, headers=headers)

    soup1=BeautifulSoup(page.content,"html.parser")
    soup2=BeautifulSoup(soup1.prettify(),"html.parser")
    #Getting the product title
    title=soup2.find(id="productTitle").get_text()
    # print(title)
    #Getting the price details
    price_all=soup2.find_all("span",{"class":"a-offscreen"})
    price=price_all[0].get_text()
    # print(price)
    #Getting rating information
    rating_all=soup2.find_all("span",{"class":"a-icon-alt"})
    rating=rating_all[0].get_text()
    # print(rating)

    title=title.strip()
    price=price.strip()[1:]
    rating=rating.strip()[:3]
    date=datetime.date.today()
    #Scraped data
    print("Product title: ",title)
    print("Price: ",price)
    print("Rating: ",rating)
    print("Date: ",date)
    data=[title,price,rating,date]
    with open('Amazon_Scraper_dataset.csv','a+',newline='',encoding='UTF8') as f:
    writer=csv.writer(f)
    writer.writerow(data)

# %%
#Code to send an email to me when price drop occurs
def send_mail():
    server = smtplib.SMTP_SSL('smtp.gmail.com',465)
    server.ehlo()
    #server.starttls()
    server.ehlo()
    server.login('saivignesh.jasti@gmail.com','xxxxxxxxxxxxxx')
    
    subject = "The 60 pack KNN Covid Mask's price is under $30"
    body = "Link here: https://www.amazon.com/Multicolor-Protective-Shields-Elastic-Grey/dp/B09P3L6D1K/ref=sr_1_2_sspa?keywords=kn95%2Bface%2Bmasks&qid=1641941355&sprefix=masks%2Caps%2C83&sr=8-2-spons&spLa=ZW5jcnlwdGVkUXVhbGlmaWVyPUEyTzEwVExKVExTREdaJmVuY3J5cHRlZElkPUEwMDI4OTU4MUY0RktJQ1k5RTdBMCZlbmNyeXB0ZWRBZElkPUEwNjk5MDA0MTBaNU9ES0lMR0c4RyZ3aWRnZXROYW1lPXNwX2F0ZiZhY3Rpb249Y2xpY2tSZWRpcmVjdCZkb05vdExvZ0NsaWNrPXRydWU&th=1"
   
    msg = f"Subject: {subject}\n\n{body}"
    
    server.sendmail(
        'saivignesh.jasti@gmail.com',
        msg
     
    )

# %%
#Checking product price every 5 seconds and hit an email when a target price drop happens
while(True):
    check_price()
    df=pd.read_csv("Amazon_Scraper_dataset.csv")
    print(df)
    if(price<30):
        send_mail()
    time.sleep(5)
